# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/test/blob/main/testtesttest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("testtesttest")
# Out:
# testtesttest
