# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/test/blob/main/Hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Hello worldを表示

print("Hello world")
# Out:
# Hello world!!

# %%
# prompt: gdrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: /content/drive/MyDrive/AI_laboratory_course/goldenretriever-3724972_640.jpgを横幅500pixで表示

from PIL import Image
import matplotlib.pyplot as plt

image_path = '/content/drive/MyDrive/AI_laboratory_course/goldenretriever-3724972_640.jpg'

try:
  img = Image.open(image_path)
  width, height = img.size
  new_width = 500
  new_height = int(height * (new_width / width))
  resized_img = img.resize((new_width, new_height))
  plt.imshow(resized_img)
  plt.axis('off')
  plt.show()

except FileNotFoundError:
  print(f"Error: Image file not found at {image_path}")
except Exception as e:
  print(f"An error occurred: {e}")
